# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#memasukan data latih
datalatih = pd.read_csv("inidata.csv")
datalatih.head()
#Prestasi Siswa = 1 == Ya 
#Prestasi Siswa = 2 == Tidak
#Prestasi Sekolah = 1 == Cukup
#Prestasi Sekolah = 2 == Baik
# Out:
#        Sekolah  Matematika  B. Inggris  B. Indonesia  Prestasi Siswa  \
# 0  SMA Negri 1          85          78            91               4
# 1  SMA Negri 2          79          78            84               4
# 2  SMA Negri 3          98          89            83               8
# 3  SMA Negri 4          82          95            87               3
# 4  SMA Negri 5          76          87            95               5
#
#    Prestasi Sekolah
# 0                 2
# 1                 1
# 2                 5
# 3                 1
# 4                 4

# %%
datalatih.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sekolah           7 non-null      object
#  1   Matematika        7 non-null      int64
#  2   B. Inggris        7 non-null      int64
#  3   B. Indonesia      7 non-null      int64
#  4   Prestasi Siswa    7 non-null      int64
#  5   Prestasi Sekolah  7 non-null      int64
# dtypes: int64(5), object(1)
# memory usage: 464.0+ bytes

# %%
from sklearn.cluster import KMeans
#Memvisualkan persebaran data
plt.scatter(datalatih.Matematika, datalatih.Sekolah, s = 75, c = "c", marker = "o", alpha = 0.5)
plt.show()

# %%
x = datalatih.drop(["Sekolah"], axis=1)
x.head(11)
# Out:
#    Matematika  B. Inggris  B. Indonesia  Prestasi Siswa  Prestasi Sekolah
# 0          85          78            91               4                 2
# 1          79          78            84               4                 1
# 2          98          89            83               8                 5
# 3          82          95            87               3                 1
# 4          76          87            95               5                 4
# 5          84          84            75               2                 1
# 6          88          85            85               2                 2

# %%
y = datalatih["Sekolah"]
y.head(11)
# Out:
# 0    SMA Negri 1
# 1    SMA Negri 2
# 2    SMA Negri 3
# 3    SMA Negri 4
# 4    SMA Negri 5
# 5    SMA Negri 6
# 6    SMA Negri 7
# Name: Sekolah, dtype: object
